# %%
import numpy as np

arr = np.random.randint(1,11,size=(5,5))
arr
# Out:
# array([[ 9,  8,  1,  7,  4],
#        [ 8,  2,  1,  8,  1],
#        [ 1,  1,  4,  1,  5],
#        [ 2,  6,  6, 10,  6],
#        [ 3,  7, 10,  6,  1]])

# %% [markdown]
# # 1. Filtering

# %% [markdown]
# `1.1) Filter elements greater than 5`

# %%
arr[arr>5]
# Out:
# array([ 9,  8,  7,  8,  8,  6,  6, 10,  6,  7, 10,  6])

# %% [markdown]
# `1.2) Filter the elements that are even`

# %%
arr[arr%2 == 0]
# Out:
# array([ 8,  4,  8,  2,  8,  4,  2,  6,  6, 10,  6, 10,  6])

# %% [markdown]
# `1.3) Filter elements that are both greather than 5 and even`

# %%
arr[(arr>5) & (arr%2 == 0)]
# Out:
# array([ 8,  8,  8,  6,  6, 10,  6, 10,  6])

# %% [markdown]
# `1.4) Filter elements that are divisible by either 3 or 7`

# %%
arr[(arr % 3 == 0) | (arr % 7 == 0)]
# Out:
# array([9, 7, 6, 6, 6, 3, 7, 6])

# %% [markdown]
# `1.5) Filter elements that based on condition on another array`

# %%
 arr1 = np.array([True, False, True,False,True])

 arr[arr1]
# Out:
# array([[ 9,  8,  1,  7,  4],
#        [ 1,  1,  4,  1,  5],
#        [ 3,  7, 10,  6,  1]])

# %% [markdown]
# `1.6 Filter the elements based on condition of specific row`

# %%
filtered_arr = arr[2][arr[2,:] > 5]

filtered_arr
# Out:
# array([], dtype=int32)

# %% [markdown]
# # 2. Aggregate Functions

# %% [markdown]
# `2.1) sum`

# %%
arr = np.array([1,2,3,4,5])
print(np.sum(arr))

arr = np.array([[1,2,3],[4,5,6]])
print(np.sum(arr))
print(np.sum(arr, axis = 0))
print(np.sum(arr, axis = 1))
# Out:
# 15
# 21
# [5 7 9]
# [ 6 15]

# %% [markdown]
# `2.2) mean`

# %%
arr = np.array([1,2,3,4,5])
print(np.mean(arr))

arr = np.array([[1,2,3],[4,5,6]])
print(np.mean(arr))
print(np.mean(arr, axis = 0))
print(np.mean(arr, axis = 1))
# Out:
# 3.0
# 3.5
# [2.5 3.5 4.5]
# [2. 5.]

# %% [markdown]
# `2.3) standard daviation`

# %%
arr = np.array([1,2,3,4,5])
print(np.std(arr))

arr = np.array([[1,2,3],[4,5,6]])
print(np.std(arr))
print(np.std(arr, axis = 0))
print(np.std(arr, axis = 1))
# Out:
# 1.4142135623730951
# 1.707825127659933
# [1.5 1.5 1.5]
# [0.81649658 0.81649658]

# %% [markdown]
# `2.4) min-max`

# %%
arr = np.array([1,2,3,4,5])
print(np.min(arr))

arr = np.array([[1,2,3],[4,5,6]])
print(np.min(arr))
print(np.min(arr, axis = 0))
print(np.min(arr, axis = 1))

print('-'*20)

arr = np.array([1,2,3,4,5])
print(np.max(arr))

arr = np.array([[1,2,3],[4,5,6]])
print(np.max(arr))
print(np.max(arr, axis = 0))
print(np.max(arr, axis = 1))
# Out:
# 1
# 1
# [1 2 3]
# [1 4]
# --------------------
# 5
# 6
# [4 5 6]
# [3 6]
