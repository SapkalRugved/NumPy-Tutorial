# %%
import numpy as np

# %%
arr = np.random.randint(low = 1, high = 101, size = 100)

mean   = np.mean(arr)
median = np.median(arr)

variance = np.var(arr)
std_dev  = np.std(arr)

q1 = np.percentile(arr, 25)
q2 = np.percentile(arr, 50)
q3 = np.percentile(arr, 75)

iqr = q3 - q1

skewness = np.mean((arr - mean) ** 3) / (std_dev ** 3)
kurtosis = np.mean((arr - mean) ** 4) / (std_dev ** 4)

print('Mean      : ', mean)
print('Median    : ', median)
# print('Mode      : ', mode)
print('-'*20)

print('Variance  : ', variance)
print('Standard  : ', std_dev)
print('-'*20)

print('Q1        : ', q1)
print('Q2        : ', q2)
print('Q3        : ', q3)
print('-'*20)

print('IQR       : ', iqr)
print('Skewness  : ', skewness)
print('Kurtosis  : ', kurtosis)
# Out:
# Mean      :  50.23
# Median    :  50.0
# --------------------
# Variance  :  707.1771000000001
# Standard  :  26.59280165759148
# --------------------
# Q1        :  24.75
# Q2        :  50.0
# Q3        :  69.75
# --------------------
# IQR       :  45.0
# Skewness  :  0.11305253339817109
# Kurtosis  :  1.9290373659323043
