# %%
import numpy as np

# %% [markdown]
# # 1. Linear Equation

# %%
A = np.array([[1,2],[3,4]])
B= np.array([[5],[6]])
solution = np.linalg.solve(A,B)
solution
# Out:
# array([[-4. ],
#        [ 4.5]])

# %%
A = np.array([[1,2,3],[4,5,6],[7,8,10]])
B = np.array([[10],[11],[12]])
solution = np.linalg.solve(A,B)
solution
# Out:
# array([[-9.33333333e+00],
#        [ 9.66666667e+00],
#        [ 3.55271368e-15]])
